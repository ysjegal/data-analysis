# %%
import pandas as pd #Analysis 
import matplotlib.pyplot as plt #Visulization
import seaborn as sns #Visulization
import numpy as np #Analysis 
from scipy.stats import norm #Analysis 
from sklearn.preprocessing import StandardScaler #Analysis 
from scipy import stats #Analysis 
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline
import gc
from matplotlib import font_manager, rc

# %%
data = pd.read_csv("data_interim.csv", encoding= "cp949")
data_log = pd.read_csv("data_interim_log.csv", encoding = "cp949")

# %%
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
data.shape
# Out:
# (26542, 359)

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.distplot(data['평균 거래금액'])

# %%
fig = plt.figure(figsize = (15,10))

fig.add_subplot(1,2,1)
res = stats.probplot(data['평균 거래금액'], plot=plt)

fig.add_subplot(1,2,2)
res = stats.probplot(np.log1p(data['평균 거래금액']), plot=plt)

# %%
data['평균 거래금액'] = np.log1p(data['평균 거래금액'])
#histogram
f, ax = plt.subplots(figsize=(8, 6))
sns.distplot(data['평균 거래금액'])

# %%
data['평균 거래금액'].describe()
# Out:
# count     26542.000000
# mean      26371.606822
# std       20562.587945
# min        2200.000000
# 25%       16625.000000
# 50%       22500.000000
# 75%       29800.000000
# max      640000.000000
# Name: 평균 거래금액, dtype: float64

# %%
data_log['log_price'].describe()
# Out:
# count    26542.000000
# mean         2.399298
# std          0.046633
# min          2.162940
# 25%          2.371992
# 50%          2.399831
# 75%          2.425006
# max          2.665089
# Name: log_price, dtype: float64

# %%
# Out:
#    Unnamed: 0  Unnamed: 0.1    평균 거래금액  평균 전용면적  평균 대지권면적    건축년도  강서구  양천구  \
# 0           0             0  10.955200    58.05     31.44  2017.0    0    0
# 1           1             1  10.778977    54.61     33.80  2015.0    0    0
# 2           2             2  10.126671    39.93     19.86  1996.0    0    0
# 3           3             3  10.657283    50.28     41.77  1989.0    0    0
# 4           4             4  10.698010    59.61     33.05  2015.0    0    0
#
#    구로구  영등포구  ...     대형마트_1st     대형마트_2nd     대형마트_3rd       공원_1st  \
# 0    0     0  ...  1991.071387  6278.494408  6707.112823  1068.371368
# 1    0     0  ...  2586.170790  5683.202109  6111.774100  1011.017913
# 2    0     0  ...  2620.906417  5648.442893  6077.009207  1042.035698
# 3    0     0  ...  2535.392878  5733.971913  6162.541952  1084.388136
# 4    0     0  ...  2363.697959  5905.730823  6334.316263  1077.701632
#
#         공원_2nd       공원_3rd       병원_1st       병원_2nd       병원_3rd  log_price
# ...
